# %%
import matplotlib.pyplot as plt

# %%
# 2 GPUs 
gurobi = [(25, 0.08508110046386719), (50, 0.31741905212402344), (75, 0.7181341648101807), (100, 1.3489925861358643), (125, 2.321063280105591), (150, 3.47944712638855), (175, 5.12633490562439), (200, 7.158405303955078), (225, 9.563724756240845), (250, 11.937131881713867)]
z3_feas = [(25, 0.25594520568847656), (50, 0.981959342956543), (75, 2.238790273666382), (100, 4.094782829284668), (125, 6.453214168548584), (150, 9.496752500534058), (175, 13.366364240646362), (200, 18.163087129592896), (225, 23.653621196746826), (250, 29.450439453125)]
z3opt = [(25, 0.23419690132141113), (50, 0.9150850772857666), (75, 1.9437358379364014), (100, 3.5848450660705566), (125, 6.172568082809448), (150, 9.15726900100708), (175, 12.562286853790283), (200, 16.593253135681152), (225, 21.504096031188965), (250, 27.45561718940735)]
boolector = [(25, 0.5381882190704346), (50, 3.617543935775757), (75, 31.951995134353638), (100, 86.47850918769836), (125, 183.3293433189392),(150,314.9739718437195), (175, 604.7767758369446), (200, 600)]

plt.plot([x for x,_ in gurobi], [y for _,y in gurobi], label="gurobi")
plt.plot([x for x,_ in z3_feas], [y for _,y in z3_feas], label="z3 feas")
# plt.plot([x for x,_ in boolector], [y for _,y in boolector], label="boolector")
plt.plot([x for x,_ in z3opt], [y for _,y in z3opt], label="z3opt")
plt.legend()
plt.xlabel("Tasks")
plt.ylabel("Time in Seconds")
plt.savefig("figure2.jpg")

# %%
gurobi =[(25, 0.08587193489074707), (50, 0.35022997856140137), (75, 0.7291121482849121), (100, 1.3141570091247559), (125, 2.1521008014678955), (150, 3.3707449436187744), (175, 5.060914993286133), (200, 6.168315887451172), (225, 8.27920413017273), (250, 9.921762704849243)]
boolector =[(25, 0.5251703262329102), (50, 2.3219339847564697), (75, 3.3040549755096436), (100, 4.810174942016602), (125, 8.076522827148438), (150, 9.844052791595459), (175, 14.263533115386963), (200, 18.89586591720581), (225, 34.64178729057312), (250, 55.9284348487854)]
z3_feas =[(25, 0.27488088607788086), (50, 0.9974880218505859), (75, 2.5175118446350098), (100, 28.96995210647583), (125, 31.289150953292847), (150, 34.28826403617859), (175, 38.13741493225098), (200, 46.34599494934082), (225, 59.39476490020752), (250, 60.48176574707031)]
z3opt =[(25, 0.640681266784668), (50, 12.719839811325073), (75, 164.75238871574402), (100, 600)]

plt.plot([x for x,_ in gurobi], [y for _,y in gurobi], label="gurobi")
plt.plot([x for x,_ in z3_feas], [y for _,y in z3_feas], label="z3 feas")
# plt.plot([x for x,_ in boolector], [y for _,y in boolector], label="boolector")
plt.plot([x for x,_ in z3opt], [y for _,y in z3opt], label="z3opt")
plt.legend()
plt.xlabel("Tasks")
plt.ylabel("Time in Seconds")
plt.savefig("figure2.jpg")

# %%
# 3 GPUs 
gurobi = [(25, 0.1027829647064209), (50, 0.39047813415527344), (75, 0.8470158576965332), (100, 1.4896490573883057), (125, 2.4311540126800537), (150, 3.8708841800689697), (175, 5.760190963745117), (200, 7.8410608768463135), (225, 10.270406723022461), (250, 12.776335954666138)]
z3_feas = [(25, 0.32239413261413574), (50, 1.8597638607025146), (75, 27.222790241241455), (100, 29.371963024139404), (125, 31.52568769454956), (150, 34.548847913742065), (175, 38.79341697692871), (200, 46.47425103187561), (225, 59.86691617965698), (250, 57.3915958404541)]
z3opt = [(25, 0.6647391319274902), (50, 13.797315120697021), (75, 164.37951588630676), (100, 610.8769950866699)]

plt.plot([x for x,_ in gurobi], [y for _,y in gurobi], label="gurobi")
plt.plot([x for x,_ in z3_feas], [y for _,y in z3_feas], label="z3 feas")
# plt.plot([x for x,_ in boolector], [y for _,y in boolector], label="boolector")
plt.plot([x for x,_ in z3opt], [y for _,y in z3opt], label="z3opt")
plt.legend()
plt.xlabel("Tasks")
plt.ylabel("Time in Seconds")
plt.savefig("figure2.jpg")

# %%
# 20 GPUs 
gurobi = [(25, 0.10733389854431152), (50, 0.4007868766784668), (75, 0.8639979362487793), (100, 1.625495195388794), (125, 2.561499834060669), (150, 4.036280870437622), (175, 5.716867208480835), (200, 7.671607971191406), (225, 10.143625020980835), (250, 12.40122389793396)]
z3_feas = [(25, 0.29245805740356445), (50, 1.0122578144073486), (75, 2.4248440265655518), (100, 6.857752084732056), (125, 19.866906881332397), (150, 34.657228231430054), (175, 39.96415400505066), (200, 52.13103103637695), (225, 66.05803108215332), (250, 64.33761286735535)]
z3opt = [(25, 0.7132937908172607), (50, 20.079652070999146), (75, 271.548504114151), (100, 610.8769950866699)]

plt.plot([x for x,_ in gurobi], [y for _,y in gurobi], label="gurobi")
plt.plot([x for x,_ in z3_feas], [y for _,y in z3_feas], label="z3 feas")
# plt.plot([x for x,_ in boolector], [y for _,y in boolector], label="boolector")
plt.plot([x for x,_ in z3opt], [y for _,y in z3opt], label="z3opt")
plt.legend()
plt.xlabel("Tasks")
plt.ylabel("Time in Seconds")
plt.savefig("figure2.jpg")
